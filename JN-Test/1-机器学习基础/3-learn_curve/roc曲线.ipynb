# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('data.csv')

X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %%
from sklearn import metrics

from sklearn.linear_model import LogisticRegression
estimator = LogisticRegression()
estimator.fit(X,y)

f1 = estimator.predict_proba(X)
f1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([[0.52932759, 0.47067241],
#        [0.48916922, 0.51083078],
#        [0.51547735, 0.48452265],
#        [0.47971594, 0.52028406],
#        [0.58497767, 0.41502233],
#        [0.39526133, 0.60473867],
#        [0.47287166, 0.52712834],
#        [0.51862161, 0.48137839],
#        [0.49967436, 0.50032564],
#        [0.50021436, 0.49978564],
#        [0.4777982 , 0.5222018 ],
#        [0.48630514, 0.51369486],
#        [0.58510126, 0.41489874],
#        [0.45233053, 0.54766947],
#        [0.47627814, 0.52372186],
#        [0.57652189, 0.42347811],
#        [0.46707816, 0.53292184],
#        [0.61091502, 0.38908498],
#        [0.53368574, 0.46631426],
#        [0.51868356, 0.48131644],
#        [0.47508706, 0.52491294],
#        [0.41654143, 0.58345857],
#        [0.51886319, 0.48113681],
#        [0.46965841, 0.53034159],
#        [0.59744017, 0.40255983],
#        [0.51881234, 0.48118766],
#        [0.56259505, 0.43740495],
#        [0.45816024, 0.54183976],
#        [0.48202854, 0.51797146],
#        [0.44208821, 0.55791179],
#        [0.52933345, 0.47066655],
#        [0.5210229 , 0.4789771 ],
#        [0.47222736, 0.52777264],
#        [0.43937862, 0.56062138],
#        [0.46505793, 0.53494207],
#        [0.49023434, 0.50976566],
#        [0.49700164, 0.50299836],
#        [0.48550364, 0.51449636],
#        [0.43947971, 0.56052029],
#        [0.52839798, 0.47160202],
#        [0.48291556, 0.51708444],
#        [0.50251894, 0.49748106],
#        [0.54120279, 0.45879721],
#        [0.38785792, 0.61214208],
#        [0.42640191, 0.57359809],
#        [0.56795667, 0.43204333],
#        [0.40340802, 0.59659198],
#        [0.36161497, 0.63838503],
#        [0.61145234, 0.38854766],
#        [0.470541  , 0.529459  ],
#        [0.45519251, 0.54480749],
#        [0.47100055, 0.52899945],
#        [0.5494682 , 0.4505318 ],
#        [0.45956652, 0.54043348],
#        [0.43060251, 0.56939749],
#        [0.55264076, 0.44735924],
#        [0.55736545, 0.44263455],
#        [0.55468805, 0.44531195],
#        [0.50377371, 0.49622629],
#        [0.44955798, 0.55044202],
#        [0.46566984, 0.53433016],
#        [0.47872072, 0.52127928],
#        [0.46129337, 0.53870663],
#        [0.5133563 , 0.4866437 ],
#        [0.42553911, 0.57446089],
#        [0.47659396, 0.52340604],
#        [0.4139883 , 0.5860117 ],
#        [0.41226544, 0.58773456],
#        [0.54892527, 0.45107473],
#        [0.43875903, 0.56124097],
#        [0.36966787, 0.63033213],
#        [0.60291793, 0.39708207],
#        [0.4489509 , 0.5510491 ],
#        [0.53315867, 0.46684133],
#        [0.5014356 , 0.4985644 ],
#        [0.39471668, 0.60528332],
#        [0.55830418, 0.44169582],
#        [0.52089975, 0.47910025],
#        [0.54961613, 0.45038387],
#        [0.51313333, 0.48686667],
#        [0.51124749, 0.48875251],
#        [0.51408344, 0.48591656],
#        [0.5679748 , 0.4320252 ],
#        [0.47629088, 0.52370912],
#        [0.5019777 , 0.4980223 ],
#        [0.44164736, 0.55835264],
#        [0.46149062, 0.53850938],
#        [0.39251065, 0.60748935],
#        [0.53003156, 0.46996844],
#        [0.49881684, 0.50118316],
#        [0.45010352, 0.54989648],
#        [0.49036417, 0.50963583],
#        [0.46435403, 0.53564597],
#        [0.43820735, 0.56179265],
#        [0.47698146, 0.52301854],
#        [0.42457256, 0.57542744],
#        [0.5833131 , 0.4166869 ],
#        [0.49428203, 0.50571797],
#        [0.53061412, 0.46938588],
#        [0.45416128, 0.54583872]])

# %%
plt.plot(fpr, tpr, marker='o')
plt.show()
